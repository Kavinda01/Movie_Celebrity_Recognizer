# %%
# !pip install opencv.python
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: opencv.python in c:\users\kavinda madushan\appdata\roaming\python\python39\site-packages (4.8.0.74)
# Requirement already satisfied: numpy>=1.17.0 in c:\programdata\anaconda3\lib\site-packages (from opencv.python) (1.24.3)

# %%
import numpy as np
import cv2
import matplotlib
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
img = cv2.imread('./test_images/leonardodicaprio1.jpg')
img.shape
# Out:
# (1092, 728, 3)

# %%
plt.imshow(img)

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
gray.shape
# Out:
# (1092, 728)

# %%
gray
# Out:
# array([[245, 245, 245, ..., 245, 245, 245],
#        [245, 245, 245, ..., 245, 245, 245],
#        [245, 245, 245, ..., 245, 245, 245],
#        ...,
#        [ 76,  94,  78, ...,   5, 104, 142],
#        [ 11,  47,  43, ...,   6,  39,  54],
#        [  1,  22,  20, ...,  13,  30,  67]], dtype=uint8)

# %%
plt.imshow(gray, cmap='gray')

# %%
face_cascade = cv2.CascadeClassifier('./opencv/haarcascades/haarcascade_frontalface_default.xml')
eye_cascade = cv2.CascadeClassifier('./opencv/haarcascades/haarcascade_eye.xml')

faces = face_cascade.detectMultiScale(gray, 1.3, 5)
faces
# Out:
# array([[107, 197, 456, 456]])

# %%
(x,y,w,h) = faces[0]
x,y,w,h
# Out:
# (107, 197, 456, 456)

# %%
face_img = cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
plt.imshow(face_img)

# %%
cv2.destroyAllWindows()
for (x,y,w,h) in faces:
    face_img = cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
    roi_gray = gray[y:y+h, x:x+w]
    roi_color = face_img[y:y+h, x:x+w]
    eyes = eye_cascade.detectMultiScale(roi_gray)
    for (ex,ey,ew,eh) in eyes:
        cv2.rectangle(roi_color,(ex,ey),(ex+ew,ey+eh),(0,255,0),2)
        

plt.figure()
plt.imshow(face_img, cmap='gray')
plt.show()

# %%
# %matplotlib inline
plt.imshow(roi_color, cmap='gray')

# %%
cropped_img = np.array(roi_color)
cropped_img.shape
# Out:
# (456, 456, 3)

# %%
def get_cropped_image_if_2_eyes(image_path):
    #img = cv2.imread(image_path)
    
    img = cv2.imread(image_path)
    if img is None:
        print("Failed to load image:", image_path)
        return None

    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray, 1.3, 5)
    for (x,y,w,h) in faces:
        roi_gray = gray[y:y+h, x:x+w]
        roi_color = img[y:y+h, x:x+w]
        eyes = eye_cascade.detectMultiScale(roi_gray)
        if len(eyes) >= 2:
            return roi_color

# %%
original_image = cv2.imread('./test_images/leonardodicaprio1.jpg')
plt.imshow(original_image)

# %%
cropped_image = get_cropped_image_if_2_eyes('./test_images/leonardodicaprio1.jpg')
plt.imshow(cropped_image)

# %%
org_image_obstructed = cv2.imread('./test_images/leonardodicaprio2.jpg')
plt.imshow(org_image_obstructed)

# %%
cropped_image_no_2_eyes = get_cropped_image_if_2_eyes('./test_images/leonardodicaprio2.jpg')
cropped_image_no_2_eyes

# %%
path_to_data = "./dataset/"
path_to_cr_data = "./dataset/cropped/"

# %%
import os
img_dirs = []
for entry in os.scandir(path_to_data):
    if entry.is_dir():
        img_dirs.append(entry.path)

# %%
img_dirs
# Out:
# ['./dataset/Gal_Gadot',
#  './dataset/leonardo_dicaprio',
#  './dataset/Michelle_Rodriguez',
#  './dataset/tom_cruise',
#  './dataset/will_smith']

# %%
import shutil
if os.path.exists(path_to_cr_data):
     shutil.rmtree(path_to_cr_data)
os.mkdir(path_to_cr_data)

# %%
cropped_image_dirs = []
celebrity_file_names_dict = {}
for img_dir in img_dirs:
    count = 1
    celebrity_name = img_dir.split('/')[-1]
    celebrity_file_names_dict[celebrity_name] = []
    for entry in os.scandir(img_dir):
        roi_color = get_cropped_image_if_2_eyes(entry.path)
        if roi_color is not None:
            cropped_folder = path_to_cr_data + celebrity_name
            if not os.path.exists(cropped_folder):
                os.makedirs(cropped_folder)
                cropped_image_dirs.append(cropped_folder)
                print("Generating cropped images in folder: ",cropped_folder)
            cropped_file_name = celebrity_name + str(count) + ".png"
            cropped_file_path = cropped_folder + "/" + cropped_file_name
            cv2.imwrite(cropped_file_path, roi_color)
            celebrity_file_names_dict[celebrity_name].append(cropped_file_path)
            count += 1
# Out:
# Generating cropped images in folder:  ./dataset/cropped/Gal_Gadot
# Generating cropped images in folder:  ./dataset/cropped/leonardo_dicaprio
# Generating cropped images in folder:  ./dataset/cropped/Michelle_Rodriguez
# Generating cropped images in folder:  ./dataset/cropped/tom_cruise
# Generating cropped images in folder:  ./dataset/cropped/will_smith
# Failed to load image: ./dataset/will_smith\will-smith-attends-varietys-creative-impact-awards-and-10-directors-to-watch-brunch-at-the-parker-palm-springs-on-january-3-2016-in-palm-springs-california-photo-by-jerod-harrisgetty-images.jpg

# %%
import numpy as np
import pywt
import cv2    

def w2d(img, mode='haar', level=1):
    imArray = img
    #Datatype conversions
    #convert to grayscale
    imArray = cv2.cvtColor( imArray,cv2.COLOR_RGB2GRAY )
    #convert to float
    imArray =  np.float32(imArray)   
    imArray /= 255;
    # compute coefficients 
    coeffs=pywt.wavedec2(imArray, mode, level=level)

    #Process Coefficients
    coeffs_H=list(coeffs)  
    coeffs_H[0] *= 0;  

    # reconstruction
    imArray_H=pywt.waverec2(coeffs_H, mode);
    imArray_H *= 255;
    imArray_H =  np.uint8(imArray_H)

    return imArray_H

# %%
im_har = w2d(cropped_image,'db1',5)
plt.imshow(im_har, cmap='gray')

# %%
celebrity_file_names_dict = {}
for img_dir in cropped_image_dirs:
    celebrity_name = img_dir.split('/')[-1]
    file_list = []
    for entry in os.scandir(img_dir):
        file_list.append(entry.path)
    celebrity_file_names_dict[celebrity_name] = file_list
celebrity_file_names_dict
# Out:
# {'Gal_Gadot': ['./dataset/cropped/Gal_Gadot\\Gal_Gadot1.png',
#   './dataset/cropped/Gal_Gadot\\Gal_Gadot10.png',
#   './dataset/cropped/Gal_Gadot\\Gal_Gadot11.png',
#   './dataset/cropped/Gal_Gadot\\Gal_Gadot12.png',
#   './dataset/cropped/Gal_Gadot\\Gal_Gadot13.png',
#   './dataset/cropped/Gal_Gadot\\Gal_Gadot14.png',
#   './dataset/cropped/Gal_Gadot\\Gal_Gadot15.png',
#   './dataset/cropped/Gal_Gadot\\Gal_Gadot16.png',
#   './dataset/cropped/Gal_Gadot\\Gal_Gadot17.png',
#   './dataset/cropped/Gal_Gadot\\Gal_Gadot18.png',
#   './dataset/cropped/Gal_Gadot\\Gal_Gadot19.png',
#   './dataset/cropped/Gal_Gadot\\Gal_Gadot2.png',
#   './dataset/cropped/Gal_Gadot\\Gal_Gadot20.png',
#   './dataset/cropped/Gal_Gadot\\Gal_Gadot21.png',
#   './dataset/cropped/Gal_Gadot\\Gal_Gadot22.png',
#   './dataset/cropped/Gal_Gadot\\Gal_Gadot23.png',
#   './dataset/cropped/Gal_Gadot\\Gal_Gadot24.png',
#   './dataset/cropped/Gal_Gadot\\Gal_Gadot25.png',
#   './dataset/cropped/Gal_Gadot\\Gal_Gadot26.png',
#   './dataset/cropped/Gal_Gadot\\Gal_Gadot27.png',
#   './dataset/cropped/Gal_Gadot\\Gal_Gadot28.png',
#   './dataset/cropped/Gal_Gadot\\Gal_Gadot29.png',
#   './dataset/cropped/Gal_Gadot\\Gal_Gadot3.png',
#   './dataset/cropped/Gal_Gadot\\Gal_Gadot30.png',
#   './dataset/cropped/Gal_Gadot\\Gal_Gadot31.png',
#   './dataset/cropped/Gal_Gadot\\Gal_Gadot32.png',
#   './dataset/cropped/Gal_Gadot\\Gal_Gadot33.png',
#   './dataset/cropped/Gal_Gadot\\Gal_Gadot34.png',
#   './dataset/cropped/Gal_Gadot\\Gal_Gadot35.png',
#   './dataset/cropped/Gal_Gadot\\Gal_Gadot36.png',
#   './dataset/cropped/Gal_Gadot\\Gal_Gadot38.png',
#   './dataset/cropped/Gal_Gadot\\Gal_Gadot39.png',
#   './dataset/cropped/Gal_Gadot\\Gal_Gadot4.png',
#   './dataset/cropped/Gal_Gadot\\Gal_Gadot40.png',
#   './dataset/cropped/Gal_Gadot\\Gal_Gadot41.png',
#   './dataset/cropped/Gal_Gadot\\Gal_Gadot42.png',
#   './dataset/cropped/Gal_Gadot\\Gal_Gadot43.png',
#   './dataset/cropped/Gal_Gadot\\Gal_Gadot44.png',
#   './dataset/cropped/Gal_Gadot\\Gal_Gadot45.png',
#   './dataset/cropped/Gal_Gadot\\Gal_Gadot46.png',
#   './dataset/cropped/Gal_Gadot\\Gal_Gadot47.png',
#   './dataset/cropped/Gal_Gadot\\Gal_Gadot48.png',
#   './dataset/cropped/Gal_Gadot\\Gal_Gadot49.png',
#   './dataset/cropped/Gal_Gadot\\Gal_Gadot5.png',
#   './dataset/cropped/Gal_Gadot\\Gal_Gadot50.png',
#   './dataset/cropped/Gal_Gadot\\Gal_Gadot51.png',
#   './dataset/cropped/Gal_Gadot\\Gal_Gadot52.png',
#   './dataset/cropped/Gal_Gadot\\Gal_Gadot53.png',
#   './dataset/cropped/Gal_Gadot\\Gal_Gadot54.png',
#   './dataset/cropped/Gal_Gadot\\Gal_Gadot55.png',
#   './dataset/cropped/Gal_Gadot\\Gal_Gadot56.png',
#   './dataset/cropped/Gal_Gadot\\Gal_Gadot57.png',
#   './dataset/cropped/Gal_Gadot\\Gal_Gadot58.png',
#   './dataset/cropped/Gal_Gadot\\Gal_Gadot59.png',
#   './dataset/cropped/Gal_Gadot\\Gal_Gadot6.png',
#   './dataset/cropped/Gal_Gadot\\Gal_Gadot60.png',
#   './dataset/cropped/Gal_Gadot\\Gal_Gadot61.png',
#   './dataset/cropped/Gal_Gadot\\Gal_Gadot62.png',
#   './dataset/cropped/Gal_Gadot\\Gal_Gadot63.png',
#   './dataset/cropped/Gal_Gadot\\Gal_Gadot65.png',
#   './dataset/cropped/Gal_Gadot\\Gal_Gadot66.png',
#   './dataset/cropped/Gal_Gadot\\Gal_Gadot67.png',
#   './dataset/cropped/Gal_Gadot\\Gal_Gadot68.png',
#   './dataset/cropped/Gal_Gadot\\Gal_Gadot69.png',
#   './dataset/cropped/Gal_Gadot\\Gal_Gadot7.png',
#   './dataset/cropped/Gal_Gadot\\Gal_Gadot70.png',
#   './dataset/cropped/Gal_Gadot\\Gal_Gadot71.png',
#   './dataset/cropped/Gal_Gadot\\Gal_Gadot73.png',
#   './dataset/cropped/Gal_Gadot\\Gal_Gadot74.png',
#   './dataset/cropped/Gal_Gadot\\Gal_Gadot75.png',
#   './dataset/cropped/Gal_Gadot\\Gal_Gadot76.png',
#   './dataset/cropped/Gal_Gadot\\Gal_Gadot77.png',
#   './dataset/cropped/Gal_Gadot\\Gal_Gadot78.png',
#   './dataset/cropped/Gal_Gadot\\Gal_Gadot8.png',
#   './dataset/cropped/Gal_Gadot\\Gal_Gadot9.png'],
#  'leonardo_dicaprio': ['./dataset/cropped/leonardo_dicaprio\\leonardo_dicaprio10.png',
#   './dataset/cropped/leonardo_dicaprio\\leonardo_dicaprio11.png',
#   './dataset/cropped/leonardo_dicaprio\\leonardo_dicaprio12.png',
#   './dataset/cropped/leonardo_dicaprio\\leonardo_dicaprio13.png',
#   './dataset/cropped/leonardo_dicaprio\\leonardo_dicaprio14.png',
#   './dataset/cropped/leonardo_dicaprio\\leonardo_dicaprio15.png',
#   './dataset/cropped/leonardo_dicaprio\\leonardo_dicaprio16.png',
#   './dataset/cropped/leonardo_dicaprio\\leonardo_dicaprio17.png',
#   './dataset/cropped/leonardo_dicaprio\\leonardo_dicaprio18.png',
#   './dataset/cropped/leonardo_dicaprio\\leonardo_dicaprio19.png',
#   './dataset/cropped/leonardo_dicaprio\\leonardo_dicaprio2.png',
#   './dataset/cropped/leonardo_dicaprio\\leonardo_dicaprio20.png',
#   './dataset/cropped/leonardo_dicaprio\\leonardo_dicaprio21.png',
#   './dataset/cropped/leonardo_dicaprio\\leonardo_dicaprio22.png',
#   './dataset/cropped/leonardo_dicaprio\\leonardo_dicaprio23.png',
#   './dataset/cropped/leonardo_dicaprio\\leonardo_dicaprio24.png',
#   './dataset/cropped/leonardo_dicaprio\\leonardo_dicaprio25.png',
#   './dataset/cropped/leonardo_dicaprio\\leonardo_dicaprio26.png',
#   './dataset/cropped/leonardo_dicaprio\\leonardo_dicaprio27.png',
#   './dataset/cropped/leonardo_dicaprio\\leonardo_dicaprio28.png',
#   './dataset/cropped/leonardo_dicaprio\\leonardo_dicaprio29.png',
#   './dataset/cropped/leonardo_dicaprio\\leonardo_dicaprio3.png',
#   './dataset/cropped/leonardo_dicaprio\\leonardo_dicaprio30.png',
#   './dataset/cropped/leonardo_dicaprio\\leonardo_dicaprio31.png',
#   './dataset/cropped/leonardo_dicaprio\\leonardo_dicaprio32.png',
#   './dataset/cropped/leonardo_dicaprio\\leonardo_dicaprio33.png',
#   './dataset/cropped/leonardo_dicaprio\\leonardo_dicaprio35.png',
#   './dataset/cropped/leonardo_dicaprio\\leonardo_dicaprio36.png',
#   './dataset/cropped/leonardo_dicaprio\\leonardo_dicaprio38.png',
#   './dataset/cropped/leonardo_dicaprio\\leonardo_dicaprio39.png',
#   './dataset/cropped/leonardo_dicaprio\\leonardo_dicaprio4.png',
#   './dataset/cropped/leonardo_dicaprio\\leonardo_dicaprio40.png',
#   './dataset/cropped/leonardo_dicaprio\\leonardo_dicaprio41.png',
#   './dataset/cropped/leonardo_dicaprio\\leonardo_dicaprio42.png',
#   './dataset/cropped/leonardo_dicaprio\\leonardo_dicaprio43.png',
#   './dataset/cropped/leonardo_dicaprio\\leonardo_dicaprio44.png',
#   './dataset/cropped/leonardo_dicaprio\\leonardo_dicaprio46.png',
#   './dataset/cropped/leonardo_dicaprio\\leonardo_dicaprio47.png',
#   './dataset/cropped/leonardo_dicaprio\\leonardo_dicaprio48.png',
#   './dataset/cropped/leonardo_dicaprio\\leonardo_dicaprio49.png',
#   './dataset/cropped/leonardo_dicaprio\\leonardo_dicaprio5.png',
#   './dataset/cropped/leonardo_dicaprio\\leonardo_dicaprio50.png',
#   './dataset/cropped/leonardo_dicaprio\\leonardo_dicaprio51.png',
#   './dataset/cropped/leonardo_dicaprio\\leonardo_dicaprio52.png',
#   './dataset/cropped/leonardo_dicaprio\\leonardo_dicaprio53.png',
#   './dataset/cropped/leonardo_dicaprio\\leonardo_dicaprio54.png',
#   './dataset/cropped/leonardo_dicaprio\\leonardo_dicaprio55.png',
#   './dataset/cropped/leonardo_dicaprio\\leonardo_dicaprio57.png',
#   './dataset/cropped/leonardo_dicaprio\\leonardo_dicaprio58.png',
#   './dataset/cropped/leonardo_dicaprio\\leonardo_dicaprio59.png',
#   './dataset/cropped/leonardo_dicaprio\\leonardo_dicaprio6.png',
#   './dataset/cropped/leonardo_dicaprio\\leonardo_dicaprio60.png',
#   './dataset/cropped/leonardo_dicaprio\\leonardo_dicaprio61.png',
#   './dataset/cropped/leonardo_dicaprio\\leonardo_dicaprio62.png',
#   './dataset/cropped/leonardo_dicaprio\\leonardo_dicaprio7.png',
#   './dataset/cropped/leonardo_dicaprio\\leonardo_dicaprio8.png',
#   './dataset/cropped/leonardo_dicaprio\\leonardo_dicaprio9.png'],
#  'Michelle_Rodriguez': ['./dataset/cropped/Michelle_Rodriguez\\Michelle_Rodriguez1.png',
#   './dataset/cropped/Michelle_Rodriguez\\Michelle_Rodriguez10.png',
#   './dataset/cropped/Michelle_Rodriguez\\Michelle_Rodriguez11.png',
#   './dataset/cropped/Michelle_Rodriguez\\Michelle_Rodriguez12.png',
#   './dataset/cropped/Michelle_Rodriguez\\Michelle_Rodriguez13.png',
#   './dataset/cropped/Michelle_Rodriguez\\Michelle_Rodriguez14.png',
#   './dataset/cropped/Michelle_Rodriguez\\Michelle_Rodriguez15.png',
#   './dataset/cropped/Michelle_Rodriguez\\Michelle_Rodriguez16.png',
#   './dataset/cropped/Michelle_Rodriguez\\Michelle_Rodriguez17.png',
#   './dataset/cropped/Michelle_Rodriguez\\Michelle_Rodriguez18.png',
#   './dataset/cropped/Michelle_Rodriguez\\Michelle_Rodriguez19.png',
#   './dataset/cropped/Michelle_Rodriguez\\Michelle_Rodriguez2.png',
#   './dataset/cropped/Michelle_Rodriguez\\Michelle_Rodriguez20.png',
#   './dataset/cropped/Michelle_Rodriguez\\Michelle_Rodriguez21.png',
#   './dataset/cropped/Michelle_Rodriguez\\Michelle_Rodriguez22.png',
#   './dataset/cropped/Michelle_Rodriguez\\Michelle_Rodriguez23.png',
#   './dataset/cropped/Michelle_Rodriguez\\Michelle_Rodriguez24.png',
#   './dataset/cropped/Michelle_Rodriguez\\Michelle_Rodriguez25.png',
#   './dataset/cropped/Michelle_Rodriguez\\Michelle_Rodriguez26.png',
#   './dataset/cropped/Michelle_Rodriguez\\Michelle_Rodriguez27.png',
#   './dataset/cropped/Michelle_Rodriguez\\Michelle_Rodriguez28.png',
#   './dataset/cropped/Michelle_Rodriguez\\Michelle_Rodriguez29.png',
#   './dataset/cropped/Michelle_Rodriguez\\Michelle_Rodriguez3.png',
#   './dataset/cropped/Michelle_Rodriguez\\Michelle_Rodriguez30.png',
#   './dataset/cropped/Michelle_Rodriguez\\Michelle_Rodriguez31.png',
#   './dataset/cropped/Michelle_Rodriguez\\Michelle_Rodriguez32.png',
#   './dataset/cropped/Michelle_Rodriguez\\Michelle_Rodriguez33.png',
#   './dataset/cropped/Michelle_Rodriguez\\Michelle_Rodriguez34.png',
#   './dataset/cropped/Michelle_Rodriguez\\Michelle_Rodriguez35.png',
#   './dataset/cropped/Michelle_Rodriguez\\Michelle_Rodriguez36.png',
#   './dataset/cropped/Michelle_Rodriguez\\Michelle_Rodriguez37.png',
#   './dataset/cropped/Michelle_Rodriguez\\Michelle_Rodriguez38.png',
#   './dataset/cropped/Michelle_Rodriguez\\Michelle_Rodriguez4.png',
#   './dataset/cropped/Michelle_Rodriguez\\Michelle_Rodriguez5.png',
#   './dataset/cropped/Michelle_Rodriguez\\Michelle_Rodriguez6.png',
#   './dataset/cropped/Michelle_Rodriguez\\Michelle_Rodriguez7.png',
#   './dataset/cropped/Michelle_Rodriguez\\Michelle_Rodriguez8.png',
#   './dataset/cropped/Michelle_Rodriguez\\Michelle_Rodriguez9.png'],
#  'tom_cruise': ['./dataset/cropped/tom_cruise\\tom_cruise1.png',
#   './dataset/cropped/tom_cruise\\tom_cruise11.png',
#   './dataset/cropped/tom_cruise\\tom_cruise12.png',
#   './dataset/cropped/tom_cruise\\tom_cruise13.png',
#   './dataset/cropped/tom_cruise\\tom_cruise15.png',
#   './dataset/cropped/tom_cruise\\tom_cruise16.png',
#   './dataset/cropped/tom_cruise\\tom_cruise17.png',
#   './dataset/cropped/tom_cruise\\tom_cruise18.png',
#   './dataset/cropped/tom_cruise\\tom_cruise19.png',
#   './dataset/cropped/tom_cruise\\tom_cruise2.png',
#   './dataset/cropped/tom_cruise\\tom_cruise20.png',
#   './dataset/cropped/tom_cruise\\tom_cruise21.png',
#   './dataset/cropped/tom_cruise\\tom_cruise22.png',
#   './dataset/cropped/tom_cruise\\tom_cruise23.png',
#   './dataset/cropped/tom_cruise\\tom_cruise24.png',
#   './dataset/cropped/tom_cruise\\tom_cruise26.png',
#   './dataset/cropped/tom_cruise\\tom_cruise27.png',
#   './dataset/cropped/tom_cruise\\tom_cruise28.png',
#   './dataset/cropped/tom_cruise\\tom_cruise29.png',
#   './dataset/cropped/tom_cruise\\tom_cruise3.png',
#   './dataset/cropped/tom_cruise\\tom_cruise30.png',
#   './dataset/cropped/tom_cruise\\tom_cruise31.png',
#   './dataset/cropped/tom_cruise\\tom_cruise32.png',
#   './dataset/cropped/tom_cruise\\tom_cruise33.png',
#   './dataset/cropped/tom_cruise\\tom_cruise34.png',
#   './dataset/cropped/tom_cruise\\tom_cruise35.png',
#   './dataset/cropped/tom_cruise\\tom_cruise37.png',
#   './dataset/cropped/tom_cruise\\tom_cruise38.png',
#   './dataset/cropped/tom_cruise\\tom_cruise39.png',
#   './dataset/cropped/tom_cruise\\tom_cruise4.png',
#   './dataset/cropped/tom_cruise\\tom_cruise40.png',
#   './dataset/cropped/tom_cruise\\tom_cruise5.png',
#   './dataset/cropped/tom_cruise\\tom_cruise6.png',
#   './dataset/cropped/tom_cruise\\tom_cruise7.png',
#   './dataset/cropped/tom_cruise\\tom_cruise8.png',
#   './dataset/cropped/tom_cruise\\tom_cruise9.png'],
#  'will_smith': ['./dataset/cropped/will_smith\\will_smith1.png',
#   './dataset/cropped/will_smith\\will_smith10.png',
#   './dataset/cropped/will_smith\\will_smith11.png',
#   './dataset/cropped/will_smith\\will_smith12.png',
#   './dataset/cropped/will_smith\\will_smith13.png',
#   './dataset/cropped/will_smith\\will_smith14.png',
#   './dataset/cropped/will_smith\\will_smith15.png',
#   './dataset/cropped/will_smith\\will_smith16.png',
#   './dataset/cropped/will_smith\\will_smith17.png',
#   './dataset/cropped/will_smith\\will_smith18.png',
#   './dataset/cropped/will_smith\\will_smith19.png',
#   './dataset/cropped/will_smith\\will_smith2.png',
#   './dataset/cropped/will_smith\\will_smith20.png',
#   './dataset/cropped/will_smith\\will_smith21.png',
#   './dataset/cropped/will_smith\\will_smith22.png',
#   './dataset/cropped/will_smith\\will_smith23.png',
#   './dataset/cropped/will_smith\\will_smith24.png',
#   './dataset/cropped/will_smith\\will_smith25.png',
#   './dataset/cropped/will_smith\\will_smith26.png',
#   './dataset/cropped/will_smith\\will_smith27.png',
#   './dataset/cropped/will_smith\\will_smith28.png',
#   './dataset/cropped/will_smith\\will_smith29.png',
#   './dataset/cropped/will_smith\\will_smith3.png',
#   './dataset/cropped/will_smith\\will_smith30.png',
#   './dataset/cropped/will_smith\\will_smith31.png',
#   './dataset/cropped/will_smith\\will_smith32.png',
#   './dataset/cropped/will_smith\\will_smith33.png',
#   './dataset/cropped/will_smith\\will_smith34.png',
#   './dataset/cropped/will_smith\\will_smith35.png',
#   './dataset/cropped/will_smith\\will_smith36.png',
#   './dataset/cropped/will_smith\\will_smith37.png',
#   './dataset/cropped/will_smith\\will_smith38.png',
#   './dataset/cropped/will_smith\\will_smith39.png',
#   './dataset/cropped/will_smith\\will_smith4.png',
#   './dataset/cropped/will_smith\\will_smith40.png',
#   './dataset/cropped/will_smith\\will_smith41.png',
#   './dataset/cropped/will_smith\\will_smith42.png',
#   './dataset/cropped/will_smith\\will_smith43.png',
#   './dataset/cropped/will_smith\\will_smith44.png',
#   './dataset/cropped/will_smith\\will_smith46.png',
#   './dataset/cropped/will_smith\\will_smith47.png',
#   './dataset/cropped/will_smith\\will_smith48.png',
#   './dataset/cropped/will_smith\\will_smith49.png',
#   './dataset/cropped/will_smith\\will_smith5.png',
#   './dataset/cropped/will_smith\\will_smith50.png',
#   './dataset/cropped/will_smith\\will_smith51.png',
#   './dataset/cropped/will_smith\\will_smith52.png',
#   './dataset/cropped/will_smith\\will_smith53.png',
#   './dataset/cropped/will_smith\\will_smith55.png',
#   './dataset/cropped/will_smith\\will_smith56.png',
#   './dataset/cropped/will_smith\\will_smith57.png',
#   './dataset/cropped/will_smith\\will_smith6.png',
#   './dataset/cropped/will_smith\\will_smith7.png',
#   './dataset/cropped/will_smith\\will_smith8.png',
#   './dataset/cropped/will_smith\\will_smith9.png']}

# %%
class_dict = {}
count = 0
for celebrity_name in celebrity_file_names_dict.keys():
    class_dict[celebrity_name] = count
    count = count + 1
class_dict
# Out:
# {'Gal_Gadot': 0,
#  'leonardo_dicaprio': 1,
#  'Michelle_Rodriguez': 2,
#  'tom_cruise': 3,
#  'will_smith': 4}

# %%
X, y = [], []
for celebrity_name, training_files in celebrity_file_names_dict.items():
    for training_image in training_files:
        img = cv2.imread(training_image)
        scalled_raw_img = cv2.resize(img, (32, 32))
        img_har = w2d(img,'db1',5)
        scalled_img_har = cv2.resize(img_har, (32, 32))
        combined_img = np.vstack((scalled_raw_img.reshape(32*32*3,1),scalled_img_har.reshape(32*32,1)))
        X.append(combined_img)
        y.append(class_dict[celebrity_name])

# %%
len(X)
# Out:
# 261

# %%
len(X[0])
# Out:
# 4096

# %%
32*32*3 + 32*32
# Out:
# 4096

# %%
X[0]
# Out:
# array([[255],
#        [182],
#        [254],
#        ...,
#        [181],
#        [182],
#        [184]], dtype=uint8)

# %%
X = np.array(X).reshape(len(X),4096).astype(float)
X.shape
# Out:
# (261, 4096)

# %%
X[0]
# Out:
# array([255., 182., 254., ..., 181., 182., 184.])

# %%
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.metrics import classification_report

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)

pipe = Pipeline([('scaler', StandardScaler()), ('svc', SVC(kernel = 'rbf', C = 10))])
pipe.fit(X_train, y_train)
pipe.score(X_test, y_test)
# Out:
# 0.8484848484848485

# %%
print(classification_report(y_test, pipe.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.80      0.94      0.86        17
#            1       0.76      0.81      0.79        16
#            2       1.00      0.89      0.94         9
#            3       1.00      0.78      0.88         9
#            4       0.86      0.80      0.83        15
#
#     accuracy                           0.85        66
#    macro avg       0.88      0.84      0.86        66
# weighted avg       0.86      0.85      0.85        66

# %%
from sklearn import svm
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import GridSearchCV

# %%
model_params = {
    'svm': {
        'model': svm.SVC(gamma='auto',probability=True),
        'params' : {
            'svc__C': [1,10,100,1000],
            'svc__kernel': ['rbf','linear']
        }  
    },
    'random_forest': {
        'model': RandomForestClassifier(),
        'params' : {
            'randomforestclassifier__n_estimators': [1,5,10]
        }
    },
    'logistic_regression' : {
        'model': LogisticRegression(solver='liblinear',multi_class='auto'),
        'params': {
            'logisticregression__C': [1,5,10]
        }
    }
}

# %%
scores = []
best_estimators = {}
import pandas as pd
for algo, mp in model_params.items():
    pipe = make_pipeline(StandardScaler(), mp['model'])
    clf =  GridSearchCV(pipe, mp['params'], cv=5, return_train_score=False)
    clf.fit(X_train, y_train)
    scores.append({
        'model': algo,
        'best_score': clf.best_score_,
        'best_params': clf.best_params_
    })
    best_estimators[algo] = clf.best_estimator_
    
df = pd.DataFrame(scores,columns=['model','best_score','best_params'])
df
# Out:
#                  model  best_score  \
# 0                  svm    0.876923
# 1        random_forest    0.651282
# 2  logistic_regression    0.856410
#
#                                     best_params
# 0        {'svc__C': 1, 'svc__kernel': 'linear'}
# 1  {'randomforestclassifier__n_estimators': 10}
# 2                  {'logisticregression__C': 1}

# %%
best_estimators
# Out:
# {'svm': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('svc',
#                   SVC(C=1, gamma='auto', kernel='linear', probability=True))]),
#  'random_forest': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('randomforestclassifier',
#                   RandomForestClassifier(n_estimators=10))]),
#  'logistic_regression': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('logisticregression',
#                   LogisticRegression(C=1, solver='liblinear'))])}

# %%
best_estimators['svm'].score(X_test,y_test)
# Out:
# 0.8636363636363636

# %%
best_estimators['random_forest'].score(X_test,y_test)
# Out:
# 0.6666666666666666

# %%
best_estimators['logistic_regression'].score(X_test,y_test)
# Out:
# 0.8636363636363636

# %%
best_clf = best_estimators['svm']

# %%
len(X_test)
# Out:
# 66

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, best_clf.predict(X_test))
cm
# Out:
# array([[16,  0,  0,  1,  0],
#        [ 2, 14,  0,  0,  0],
#        [ 1,  1,  7,  0,  0],
#        [ 0,  0,  1,  7,  1],
#        [ 1,  1,  0,  0, 13]], dtype=int64)

# %%
import seaborn as sn
plt.figure(figsize = (10,7))
sn.heatmap(cm, annot=True)
plt.xlabel('Predicted')
plt.ylabel('Truth')
# Out:
# Text(95.72222222222221, 0.5, 'Truth')

# %%
class_dict
# Out:
# {'Gal_Gadot': 0,
#  'leonardo_dicaprio': 1,
#  'Michelle_Rodriguez': 2,
#  'tom_cruise': 3,
#  'will_smith': 4}

# %%
# !pip install joblib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: joblib in c:\users\kavinda madushan\appdata\roaming\python\python39\site-packages (1.3.1)

# %%
import joblib 
# Save the model as a pickle in a file 
joblib.dump(best_clf, 'saved_model.pkl')
# Out:
# ['saved_model.pkl']

# %%
import json
with open("class_dictionary.json","w") as f:
    f.write(json.dumps(class_dict))
